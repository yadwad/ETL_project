# %%
import pandas as pd

# %%
insurance = pd.read_csv("Health/insurance.csv")
insurance.head(10)
# Out:
#                   State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0              Alabama                 14.60%                10.10%
# 1               Alaska                 19.90%                14.90%
# 2              Arizona                 16.90%                10.80%
# 3             Arkansas                 17.50%                 9.50%
# 4            California                18.50%                 8.60%
# 5              Colorado                15.90%                 8.10%
# 6           Connecticut                 9.10%                    6%
# 7             Delaware                  9.70%                 5.90%
# 8  District of Columbia                 7.60%                 3.80%
# 9              Florida                 21.30%                13.30%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.50%
# 1                               -5%
# 2                            -6.10%
# 3                               -8%
# ...

# %%
# reading in income csv dataset
income_location = pd.read_csv("Income/Income_state.csv", encoding = "ISO-8859-1")
income_location.head(10)
# Out:
#         id  State_Code State_Name State_ab            County            City  \
# 0  1011000           1    Alabama       AL     Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL    Barbour County      Louisville
# 2  1011020           1    Alabama       AL     Shelby County      Columbiana
# 3  1011030           1    Alabama       AL     Mobile County         Satsuma
# 4  1011040           1    Alabama       AL     Mobile County  Dauphin Island
# 5  1011050           1    Alabama       AL    Cullman County         Cullman
# 6  1011060           1    Alabama       AL   Escambia County    East Brewton
# 7  1011070           1    Alabama       AL     Elmore County         Coosada
# 8  1011080           1    Alabama       AL     Morgan County             Eva
# 9  1011090           1    Alabama       AL  Talladega County       Sylacauga
#
#                Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# ...

# %%
# renaming columns for consistency
income_location.rename(columns = {"State_Name":"State", "Median":"Median Income"}, inplace = True)
income_location.head()
# Out:
#         id  State_Code    State State_ab          County            City  \
# 0  1011000           1  Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1  Alabama       AL  Barbour County      Louisville
# 2  1011020           1  Alabama       AL   Shelby County      Columbiana
# 3  1011030           1  Alabama       AL   Mobile County         Satsuma
# 4  1011040           1  Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median Income  Stdev        sum_w
# ...

# %%
insurance.groupby(State)
print(insurance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-75d9cc508701> in <module>
# ----> 1 insurance.groupby(State)
#       2 print(insurance)
#
# NameError: name 'State' is not defined

# %%
print (income_location)
# Out:
#             id  State_Code        State State_ab              County  \
# 0      1011000           1      Alabama       AL       Mobile County
# 1      1011010           1      Alabama       AL      Barbour County
# 2      1011020           1      Alabama       AL       Shelby County
# 3      1011030           1      Alabama       AL       Mobile County
# 4      1011040           1      Alabama       AL       Mobile County
# 5      1011050           1      Alabama       AL      Cullman County
# 6      1011060           1      Alabama       AL     Escambia County
# 7      1011070           1      Alabama       AL       Elmore County
# 8      1011080           1      Alabama       AL       Morgan County
# 9      1011090           1      Alabama       AL    Talladega County
# 10     1011100           1      Alabama       AL       DeKalb County
# 11     1011110           1      Alabama       AL       Etowah County
# 12     1011120           1      Alabama       AL       Butler County
# ...

# %%
print(insurance)
# Out:
#                    State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0               Alabama                 14.60%                10.10%
# 1                Alaska                 19.90%                14.90%
# 2               Arizona                 16.90%                10.80%
# 3              Arkansas                 17.50%                 9.50%
# 4             California                18.50%                 8.60%
# 5               Colorado                15.90%                 8.10%
# 6            Connecticut                 9.10%                    6%
# 7              Delaware                  9.70%                 5.90%
# 8   District of Columbia                 7.60%                 3.80%
# 9               Florida                 21.30%                13.30%
# 10              Georgia                 19.70%                13.90%
# 11                Hawaii                 7.90%                    4%
# 12                 Idaho                17.70%                   11%
# ...

# %%
df = pd.merge(insurance, how='outer', sort=True, on=["State"])
df.head()

# %%
df = df[df["ZIP_CODE"]!=0]

# %%
test = income_location[income_location["County"]!="Mobile County"]

# %%
test = income_location[income_location["County"] ==("Barbour County""Cullman County")]

# %%
test
# Out:
#              id  State_Code          State State_ab          County  \
# 1       1011010           1        Alabama       AL  Barbour County
# 31156   5401602          54  West Virginia       WV  Barbour County
# 31163   5401672          54  West Virginia       WV  Barbour County
# 31190    540210          54  West Virginia       WV  Barbour County
# 31191   5402100          54  West Virginia       WV  Barbour County
# 31192  54021000          54  West Virginia       WV  Barbour County
# 31193  54021010          54  West Virginia       WV  Barbour County
# 31194  54021020          54  West Virginia       WV  Barbour County
# 31195  54021030          54  West Virginia       WV  Barbour County
# 31196  54021040          54  West Virginia       WV  Barbour County
# 31197  54021050          54  West Virginia       WV  Barbour County
# 31198  54021060          54  West Virginia       WV  Barbour County
# 31199  54021070          54  West Virginia       WV  Barbour County
# ...

# %%
# drop NaN values
new = new.dropna()

# %%
new = new[new["ZIP_CODE"]!=0]
new = new[new["ZIP_CODE"]!=83]

# %%
df['ZIP_CODE_STR'] = df['ZIP_CODE'].astype(int).astype(str)

# %%
test = new['ZIP_CODE_STR'] = new['ZIP_CODE'].astype(int).astype(str)
